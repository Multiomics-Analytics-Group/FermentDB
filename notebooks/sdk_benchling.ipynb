# %% [markdown]
# # SDK for Interacting with the Benchling Platform

# %% [markdown]
# Link: https://docs.benchling.com/docs/getting-started-with-the-sdk
#
# https://benchling.com/sdk-docs/1.20/benchling_sdk.services.v2.stable.mixture_service.html#benchling_sdk.services.v2.stable.mixture_service.MixtureService

# %%
# %pip install benchling-sdk
#pip show becnhling-sdk

# %%
from benchling_sdk.benchling import Benchling
from benchling_sdk.auth.api_key_auth import ApiKeyAuth # User API key Auth Object
import os
import json
import csv
from datetime import datetime
import sys

sys.path.append('../notebooks/benchling')


# Define output path
output_dir = '../output'

from config import USER_API_KEY

# %%
benchling = Benchling(
    url="https://biosustain.benchling.com", 
    auth_method=ApiKeyAuth(USER_API_KEY)
)

# try:

#     exampleEntries = benchling.entries.list_entries()
#     entry = next(exampleEntries, None)
#     #print(type(entry))

#     if entry is None:
#         print("No entries available.")
#     elif len(entry) == 0:
#         print("Entry is empty")    
#     else:
#         #print(entry)
#         print("ok")

# except Exception as e:
#     print(f"An error ocurred: {e}")

# %%
# Test Call
example_entities = benchling.dna_sequences.list()
for page in example_entities:
  for sequence in page:
    print(f"name: {sequence.name}\nid:{sequence.id}\n")
# Out:
# name: pMC0_5_6_02_3'Con2_operon
# id:seq_CDpnl0Bu
#
# name: pMC0_7_03_OpMB1-M
# id:seq_Yz0Y5YI4
#
# name: pMC0_2_33_PRham_(Vn)
# id:seq_mYb1rlCu
#
# name: Pput_eamA_TB1010
# id:seq_rQ7k9Us8
#
# name: Eco_serC
# id:seq_xfx8s0yM
#
# name: pMC0_1_2_03_5'Con3_operon
# id:seq_irKbYsJI
#
# name: P.put_serC
# id:seq_sMYZmFKM
#
# name: P.put_serB
# id:seq_uKTJlnxm
#
# name: pMC0_1_2_04_5'Con4_operon
# id:seq_Dwb8VMUH
#
# name: P.put_eamA
# id:seq_w25amjfv
#
# name: pMC0_4_GALS_P.p.
# id:seq_vCvRp8fM
#
# name: pCBB2.0 Rbc9
# id:seq_vf7mBpX2
#
# name: pCBB2.0 Rbc10
# id:seq_DEh8q0Zh
#
# name: pCBB2.0 Rbc8
# id:seq_PPGsN7Ym
#
# name: pCBB2.0 Rbc7
# id:seq_Host9AFu
#
# name: pCBB2.0 Rbc6
# id:seq_czXxMoIy
#
# name: pCBB2.0 Rbc5
# id:seq_lKcqbD1c
#
# name: pCBB2.0 Rbc3
# id:seq_awyatBgn
#
# name: pCBB2.0 Rbc2
# id:seq_80FWcRV6
#
# name: pCBB2.0 Rbc1
# id:seq_jv4MdUQY
#
# name: pCBB2.0 Rbc4
# id:seq_cd8BE3U2
#
# name: Copy of pCBB2.0_ru_rbc_prk9_optRBS2.0
# id:seq_QqKGS36R
#
# name: pESC-URA-apvA-CDS-BsaI-free
# id:seq_hUcaOaw2
#
# name: pSIBR_fbp_sp1
# id:seq_SWXKLbpM
#
# name: oLJ_018
# id:seq_vAQ62Xmo
#
# name: oLJ_019
# id:seq_1khY6i7A
#
# name: pET-28b(+)
# id:seq_rgshJzCh
#
# name: pET-28b(+)-mCherry
# id:seq_Pfiz60F5
#
# name: pET-28b(+)-GFP
# id:seq_9TRs1isZ
#
# name: pET-28b(+)-mApple
# id:seq_7Zuhhjd4
#
# name: pET-28b(+)-CyPet
# id:seq_3uOOwScS
#
# name: oLJ_017
# id:seq_2nHi67bK
#
# name: oLJ_016
# id:seq_TiWxfnLs
#
# name: pSIBR_fbp_sp3
# id:seq_A8p08yZC
#
# name: pSIBR_fbp_sp2
# id:seq_zD1WFEiH
#
# name: pUC18
# id:seq_SLSYKzgH
#
# name: oLJ_015
# id:seq_G6zyj6bt
#
# name: oLJ_014
# id:seq_JenG1QJd
#
# name: oLJ_013
# id:seq_NRTC8ln3
#
# name: oLJ_012
# id:seq_LaoiScUo
#
# name: oLJ_010
# id:seq_HQ8EMBEk
#
# name: oLJ_011
# id:seq_zW3hBhTX
#
# name: oLJ_007
# id:seq_zZ5mbH9W
#
# name: oLJ_009
# id:seq_qIE48JCG
#
# name: oLJ_008
# id:seq_2blmKbXX
#
# name: oLJ_006
# id:seq_DozLV7eV
#
# name: NZ_CP039288 (Chr 2)
# id:seq_3pYhGorJ
#
# name: sp3_fbp
# id:seq_DiBelslR
#
# name: sp2_fbp
# id:seq_CKuVhCrK
#
# name: sp1_fbp
# id:seq_iIpa5vFB
#
# name: CN_Chr2
# id:seq_atjtNSu2
#
# name: NZ_CP039287 (Chr 1)
# id:seq_UB2mUluY
#
# name: test_0511
# id:seq_HETu1yjE
#
# name: pSEVA231 + Ptrc GFP
# id:seq_b4hU0fdX
#
# name: pSEVA231 + Prpsl GFP
# id:seq_8YaLvTmu
#
# name: pSEVA231 + P14 GFP
# id:seq_cqexRLKD
#
# name: pSEVA231 + Pj5 GFP
# id:seq_pRyTLVMR
#
# name: pSEVA231 + P4 GFP
# id:seq_mcGA74bP
#
# name: pSEVA231 + P3 GFP
# id:seq_ThUm12T0
#
# name: FF221_pSxx13_fw
# id:seq_pOO8akx4
#
# name: pSEVA231 + P2 GFP
# id:seq_pDLJcbSb
#
# name: tdcG-III genomic region
# id:seq_ZY7v9MOh
#
# name: pSEVA231 + P14g GFP (fra)
# id:seq_n0hXrh0K
#
# name: pEX128-gRNAtemp_TDCG
# id:seq_48DYt7NJ
#
# name: CN_Chr1
# id:seq_oBQ5abua
#
# name: GFP
# id:seq_Py1YH9vZ
#
# name: Y11520
# id:seq_2mQ3WbwA
#
# name: chr11:5225464:5229395
# id:seq_dfa5Apdc
#
# name: BBa_K156014
# id:seq_MNSiulOf
#
# name: pCAT
# id:seq_YsTniulT
#
# name: pET-28b(+)
# id:seq_SeO5ESaI
#
# name: pBG42
# id:seq_En9KV5Ds
#
# name: chr11:5225464:5229395
# id:seq_LDZnOMAt
#
# name: XXT3-201 (AT5G07720.1)
# id:seq_P8tyNgBM
#
# name: BRCA2-201 (ENST00000380152)
# id:seq_f5uzNjsu
#
# name: Untitled sequence
# id:seq_FKgXDKJ4
#
# name: pTNS2
# id:seq_ZVBUpwQP
#
# name: pBG37
# id:seq_ZWuQRJhU
#
# name: Pput_serA_MUT
# id:seq_vwXCtGY9
#
# name: pET28a(+)-TEV_FlAma37 [2646-3593]
# id:seq_6gMaiMim
#
# name: pUC18-GFP
# id:seq_mJqr6TEu
#
# name: pCIFR-4-xylABE
# id:seq_nInRlX6M
#
# name: pEX128-gRNAtemp
# id:seq_5Om8yCsX
#
# name: oEO_567
# id:seq_d7ECG3Wv
#
# name: oEO_566
# id:seq_XIFh69Cb
#
# name: oEO_565
# id:seq_2y5qYKcE
#
# name: oEO_564
# id:seq_hWQMxHjx
#
# name: oEO_551
# id:seq_3GXXpZeq
#
# name: oEO_550
# id:seq_ueP13Ijd
#
# name: pBAMD1-4R-p14g-BCD2-msGFP
# id:seq_KxtG5foI
#
# name: pMBEC2.0
# id:seq_0GsDauzL
#
# name: oEO_563
# id:seq_66DCnGLa
#
# name: oEO_562
# id:seq_YwXJxWRS
#
# name: oEO_561
# id:seq_XTBAjikq
#
# name: oEO_560
# id:seq_0A3ZUuqE
#
# name: oEO_559
# id:seq_GuOuHYo1
#
# name: oEO_558
# id:seq_cBTP7fyy
#
# name: oEO_557
# id:seq_KAqj8MjE
#
# name: oEO_556
# id:seq_ANmn7tIr
#
# name: oEO_555
# id:seq_anGBicW9
#
# name: oEO_554
# id:seq_iPyrWwiz
#
# name: pSEVA231
# id:seq_So7u3NT4
#
# name: oEO_549
# id:seq_7dedMiJk
#
# name: oEO_546
# id:seq_rUjGomgO
#
# name: oEO_547
# id:seq_ia9PKrg3
#
# name: oEO_548
# id:seq_f1dkaQVI
#
# name: pSEVA231 w/ msfGFP + promoter
# id:seq_QWTVS6sq
#
# name: template pCBB2.0 rubiscos
# id:seq_uMgOkVc7
#
# name: chr1:3087714-3088928
# id:seq_HLhEREwC
#
# name: Pput_serA
# id:seq_B5zdVPeS
#
# name: Eco_serA
# id:seq_99mdpg7M
#
# name: Eco_serA_MUT
# id:seq_0SiyGtiq
#
# name: Eco_serB
# id:seq_GI2JNlDF
#
# name: P.put_serB
# id:seq_w3rsZnNn
#
# name: Eco_serC
# id:seq_bVwiS74T
#
# name: Eco_eamA
# id:seq_2ibuqOD4
#
# name: P.put_eamA
# id:seq_V8MpIV7J
#
# name: pMC0_4_72_RuBisCO2
# id:seq_gXdIj7Z4
#
# name: assembly 1
# id:seq_tj0jbpfL
#
# name: Y11520 [1752-3234] [1-1482]
# id:seq_uPw5NOp8
#
# name: Y11520 [1752-3234]
# id:seq_c8pHiqVe
#
# name: rev1
# id:seq_FUkYC1kc
#
# name: fwd1
# id:seq_ASFMyuVh
#
# name: Y11520
# id:seq_nNYt93Iv
#
# name: pUC18-vdh
# id:seq_VH3YbrZG
#
# name: ligation test
# id:seq_cU9BnHoo
#
# name: Y11520 3317-3338 REV 4
# id:seq_jYzRozhl
#
# name: Y11520 2350-2371 FWD 4
# id:seq_JQcoCSQT
#
# name: Y11520 3317-3338 REV 3
# id:seq_Ugk7nhPu
#
# name: Y11520 2547-2568 FWD 3
# id:seq_4DDbNlCP
#
# name: vdh_rev
# id:seq_egchLoMu
#
# name: vdh_fwd
# id:seq_XHzCQDsG
#
# name: vdh [1770-3264]
# id:seq_TfzEaD3j
#
# name: vdh
# id:seq_lmfvx9B1
#
# name: pUC18
# id:seq_KkGd2ETD
#
# name: pUC18
# id:seq_99V6T1W4
#
# name: vdh [1781-3300]
# id:seq_Sdg8CaUE
#
# name: Y11520 3339-3360 REV 2
# id:seq_jZB9YNIs
#
# name: Y11520 1704-1725 FWD 2
# id:seq_s3ETe6gJ
#
# name: Y11520 3339-3360 REV 1
# id:seq_iQlQaTOn
#
# name: Y11520 1464-1485 FWD 1
# id:seq_JDALt4YK
#
# name: downstream
# id:seq_YOkq2rWs
#
# name: vdh
# id:seq_cc9FY6Z3
#
# name: vdh_rv
# id:seq_0yKlDT2h
#
# name: vdh_fw
# id:seq_tBgFdX5j
#
# name: pUC18
# id:seq_nNHULwTV
#
# name: GFP
# id:seq_WpRY9fGD
#
# name: pUC18
# id:seq_tnWUSZSP
#
# name: GFP
# id:seq_Zkp3wMHP
#
# name: GFP
# id:seq_526bJluP
#
# name: pUC18
# id:seq_VusvmHkI
#
# name: GFP
# id:seq_mSRMyKft
#
# name: GFP
# id:seq_aDIdix5n
#
# name: vdh
# id:seq_zcKhiCn8
#
# name: vdh
# id:seq_qWgsHfaT
#
# name: pSEVA2213_xylABE (298)
# id:seq_A1KQ8D21
#
# name: pSEVA2313::rpeWT
# id:seq_eXPIltuj
#
# name: M2-32
# id:seq_PZaME128
#
# name: pSIBR2.0_acoC_sp5_HR
# id:seq_dO2FXEB2
#
# name: pSEVA2313::rpe*
# id:seq_DLNYUpN5
#
# name: pUC18-vdh-GFP
# id:seq_ZYm5Ss5C
#
# name: vdh_fw
# id:seq_Yd6SniKI
#
# name: Y11520 [1781-3257]
# id:seq_yAnGQOKs
#
# name: Y11520
# id:seq_S30EAtUy
#
# name: assembly_vdh
# id:seq_RQMrZ1iY
#
# name: pUC18
# id:seq_ovmh9F3J
#
# name: pUC18-vdh
# id:seq_kcQzv5Bc
#
# name: vdh_rv
# id:seq_8PcLJiW9
#
# name: GFP
# id:seq_7q1HSopT
#
# name: pETDuet - B.sub Acs
# id:seq_pLd2WNdB
#
# name: vdh_pUC18
# id:seq_VIAjKcoM
#
# name: Y11520 1464-1485 FWD 1
# id:seq_raNbon63
#
# name: pUC18-Y11520 [1781-3258]-GFP
# id:seq_ojb65f3U
#
# name: Y11520 3339-3360 REV 1
# id:seq_HbSM0vFK
#
# name: Y11520
# id:seq_FUyXwEcY
#
# name: Y11520 [1781-3258]
# id:seq_CXEPBVre
#
# name: PP_2930 genomic region
# id:seq_vQcNoHad
#
# name: tdcG-I genomic region
# id:seq_JusqafED
#
# name: tdcG-II genomic region
# id:seq_GBWCvBLz
#
# name: SEM11_P._putida
# id:seq_y80VHwHu
#
# name: MkCoATpET28a(+)-NtHis6x-TEV_MND
# id:seq_JAQwLAqy
#
# name: LpCoAT pET28a(+)-NtHis6x-TEV_MND
# id:seq_t6bGos1O
#
# name: GaCoATpET28a(+)-NtHis6x-TEV_MND
# id:seq_MmAxRTVJ
#
# name: AaCoAT_pET28a(+)-NtHis6x-TEV_MND
# id:seq_0D8nBJPh
#
# name: pSEVA2313
# id:seq_RbZXmUZp
#
# name: Y11520
# id:seq_qO41tDef
#
# name: Consensus_alignment
# id:seq_tGBGyNVp
#
# name: test_fwd
# id:seq_QlwV2yjK
#
# name: test_assembly
# id:seq_ndl748PY
#
# name: test_rv
# id:seq_jtsPaZZ3
#
# name: pUC18
# id:seq_gCMo6Mf9
#
# name: Y11520 [1786-3242]
# id:seq_Eda5Ee9h
#
# name: pMBEC2.0
# id:seq_VOML46cI
#
# name: pSIBR004-Cas9_sp5_acoC_HR
# id:seq_tQteEo5g
#
# name: pSEVA2311mutLE36K-SacB
# id:seq_qvEikOVl
#
# name: GFP
# id:seq_55Y0iqgR
#
# name: pCLA045 (for GFP sequence)
# id:seq_Qo796myR
#
# name: nagR
# id:seq_sgcOrH3T
#
# name: pyrF
# id:seq_5quiVJiW
#
# name: pSEVA2311-mutLE36K-sacB
# id:seq_FglOjr2e
#
# name: Copy of pS448∙CsR-tpiA_2 458-459
# id:seq_WEQjY0rK
#
# name: oEO_525
# id:seq_bdnUTjsM
#
# name: oEO_524
# id:seq_xaekBf1p
#
# name: pMBEC_GFP_sp1
# id:seq_2HfZmHtg
#
# name: rpsL
# id:seq_ou7G06vu
#
# name: rpsL gene - mutL
# id:seq_jw3NLrDw
#
# name: PR_NW_570
# id:seq_zcuGzrtN
#
# name: gcl gene
# id:seq_xfdMtJg9
#
# name: pMBEC_pyrF_T_sp1
# id:seq_3AhiZUkE
#
# name: ppsA gene-knock out
# id:seq_WX0hc9IC
#
# name: pMBEC_pyrF_T_sp2
# id:seq_r4bWQMzx
#
# name: pMBEC_pyrF_T_sp3
# id:seq_0deBK9YP
#
# name: pMBEC
# id:seq_1HXI46z5
#
# name: glcEF with FS1 & FS2
# id:seq_0XqjGCoQ
#
# name: acoC with FS1 & FS2
# id:seq_l9pUuOiH
#
# name: Copy of NZ_CP039288_Chr2
# id:seq_e6cxvtpZ
#
# name: pSIBR2.0
# id:seq_bkDUtwbM
#
# name: pSIBR2.0_NT
# id:seq_Ne2UEzwm
#
# name: pSIBR2.0_acoC_NT_HR
# id:seq_C2r1E2hl
#
# name: pSIBR-Cas9_int4
# id:seq_Kw65AE4R
#
# name: pSIBR-Cas9_int4
# id:seq_o822wZG8
#
# name: TmACoATpET28a(+)-NtHis6x-TEV_AS
# id:seq_tiQ1YdTL
#
# name: PgBCoAT pET28a(+)-NtHis6x-TEV_AS
# id:seq_88xKvLKp
#
# name: Labeled_as_TmCoAT_190_EF72674693
# id:seq_JmKt8Bis
#
# name: Labeled_as_TmCoAT_96_EF72674689
# id:seq_mYMMoUOo
#
# name: Labeled_as_NvCoAT_190_EF72674692
# id:seq_vvuPemBd
#
# name: Labeled_as_NvCoAT_96_EF72674688
# id:seq_T8sju1o2
#
# name: Labeled_as_PgCoAT_190_EF72674691
# id:seq_0i2rarZN
#
# name: Labeled_as_PgCoAT_96_EF72674687
# id:seq_Db0pNoft
#
# name: Labeled_as_GaCoAT_190_EF72674690
# id:seq_rNWxiv07
#
# name: Labeled_as_GaCoAT_96_EF72674686
# id:seq_NG1FvAZP
#
# name: pMBEC_phaC_T_sp3
# id:seq_75bj6FUv
#
# name: p4S + RBS A eda + RBS 19 sacB
# id:seq_pnst4Aye
#
# name: Copy of p4S + RBS B eda + RBS 16 sacB
# id:seq_9hxR9ydH
#
# name: pMBEC_nagR_T_sp3
# id:seq_JYfPgVh4
#
# name: pMBEC_phaC_T_sp2
# id:seq_iRYy4OAa
#
# name: pSEVA231MBEC-sacB (SEVArised) 2.0
# id:seq_8xrTVEvK
#
# name: pEX128-gRNAtemp_set1
# id:seq_Qnz7HQlj
#
# name: pMBEC_nagR_T_sp2
# id:seq_NADku6xT
#
# name: pSIBR2.0_acoC_sp5
# id:seq_cu4y5pap
#
# name: oEO_489
# id:seq_dCZB4WZo
#
# name: oEO_488
# id:seq_xIaOndZF
#
# name: Destroyed pSEVA231SIBR4-Cas9-sacB_NT_HR
# id:seq_NSk0O6sS
#
# name: fbp HR
# id:seq_IrpmH7fS
#
# name: NvECoAT pET28a(+)-NtHis6x-TEV_AS
# id:seq_6dWnV2hf
#
# name: AjCoATpET28a(+)-NtHis6x-TEV_AS
# id:seq_5uyZgDYx
#
# name: Labeled as NvCoAT_BL21_190_EF72674685
# id:seq_eJ3utXL1
#
# name: Labeled as LpCoAT_BL21_190_EF72674684
# id:seq_h8OqCs87
#
# name: Labeled as AjCoAT_BL21_190_EF72674683
# id:seq_qVU4BUC3
#
# name: Labeled as AaCoAT_BL21_190_EF72674682
# id:seq_hhYYpsZB
#
# name: Labeled as MkCoAT_BL21_190_EF72674681
# id:seq_ix9oSRcr
#
# name: Labeled as GaCoAT_BL21_190_EF72674680
# id:seq_jol8XugA
#
# name: Labeled as PgCoAT_BL21_190_EF72674679
# id:seq_60Brw8XQ
#
# name: Labeled as TmCoAT_BL21_190_EF72674678
# id:seq_YIQ661gw
#
# name: pMBEC_nagR_T_sp1
# id:seq_OYTpJCFf
#
# name: pMBEC_phaC_T_sp1
# id:seq_bSeH24Fy
#
# name: phaC
# id:seq_L5sQ9OaF
#
# name: Copy of SEM10_P._putida_in_progress
# id:seq_fnHn92gj
#
# name: PR_NW_569
# id:seq_RjLaK1VG
#
# name: PR_EC_243_rpsL_rv
# id:seq_pkRxSdh6
#
# name: PR_243_rpsL
# id:seq_W15qufbG
#
# name: pSNW2∙ΔtpiA-SmR-SWAP
# id:seq_aps6qh4S
#
# name: pSNW2∙Δfbp
# id:seq_bMXiTER9
#
# name: Copy of SIJ488_Ari
# id:seq_2XPPrDpZ
#
# name: oEO_517
# id:seq_BV6jBA9H
#
# name: oEO_518
# id:seq_x5mvAY1I
#
# name: oEO_516
# id:seq_HLBii5yQ
#
# name: oEO_515
# id:seq_1Ignr1nF
#
# name: pSIBR-Cas9_Constitutive_sp5_acoC_HR
# id:seq_jiX0WV58
#
# name: pSIBR-Cas9_Int4_acoC-sp5
# id:seq_R78pR3gI
#
# name: oEO_514
# id:seq_Z0sggTuL
#
# name: oEO_513
# id:seq_wQh6uZHp
#
# name: oEO_512
# id:seq_mczK3yfg
#
# name: oEO_511
# id:seq_V3D72VRP
#
# name: acoC_C.necator
# id:seq_qUqPqq0y
#
# name: delta_acoC-C.necator
# id:seq_ZWom7zGL
#
# name: acoC (CLA001)
# id:seq_ycFmTCSV
#
# name: pSEVA64MBEC (SEVArised) REV
# id:seq_839O2P1t
#
# name: pSEVA64MBEC (SEVArised) FWD
# id:seq_029pigkw
#
# name: pSEVA231 REV
# id:seq_LaclBmv3
#
# name: pSEVA231 FWD
# id:seq_JdvGmv3X
#
# name: pSEVA64MBEC (SEVArised) REV
# id:seq_zp2rmWrQ
#
# name: pSEVA64MBEC (SEVArised) FWD
# id:seq_Su2M5xVb
#
# name: pSEVA231 REV
# id:seq_1BSNVr01
#
# name: pSEVA231 FWD
# id:seq_oP78HYdI
#
# name: pSEVA64MBEC (SEVArised)
# id:seq_tEj2647R
#
# name: pSEVA64MBEC (SEVArised) REV
# id:seq_ErUm8A0H
#
# name: pSEVA64MBEC (SEVArised) FWD
# id:seq_vp7tKpyP
#
# name: pSEVA231 REV
# id:seq_jEOx6VEC
#
# name: pSEVA231 FWD
# id:seq_MvE2ySii
#
# name: pSEVA64MBEC (SEVArised) REV
# id:seq_2Gpq1ky2
#
# name: pSEVA64MBEC (SEVArised) FWD
# id:seq_zPLg9eqq
#
# name: pSEVA231 REV
# id:seq_tOB8qFb9
#
# name: pSEVA231 FWD
# id:seq_Bdl3P5Ud
#
# name: pSEVA64MBEC-sacB
# id:seq_pDHU0Cy4
#
# name: pSIBR-Cas9_Constitutive_NT_acoC_HR
# id:seq_014eBSjK
#
# name: pSIBR004-Cas9_NT_acoC_HR
# id:seq_JcuQP5P4
#
# name: pSIBR016-Cas9_sp2 glcF
# id:seq_8s6PYv0B
#
# name: pSIBR013-Cas9_NTgRNA
# id:seq_DD6iPToq
#
# name: pSIBR004-Cas9_NTgRNA_HR
# id:seq_g5hSKaij
#
# name: oEO_510
# id:seq_A5NLzGOt
#
# name: oEO_509
# id:seq_F4V286b5
#
# name: oEO_507
# id:seq_dKOP9Puy
#
# name: oEO_508
# id:seq_kNOUrlN5
#
# name: Copy of pSIBR-Cas9_Int4_NT_EV
# id:seq_esrSz4vV
#
# name: Copy of pSIBR-Cas9_Int3_NT_EV
# id:seq_3Y0L1sKK
#
# name: Copy of pSIBR-Cas9_Int2_NT_EV
# id:seq_bf73dy2v
#
# name: Copy of pSIBR-Cas9_Constitutive_NT_EV
# id:seq_UgfWNvVZ
#
# name: delta_glcEF locus (CLA001)
# id:seq_x4XCT4kQ
#
# name: glcEF locus (CLA001)
# id:seq_gZ89WpZs
#
# name: pSIBR-Cas9_Int4_acoC-sp5
# id:seq_Q6YzvsA1
#
# name: oEO_506
# id:seq_53voatEJ
#
# name: oEO_505
# id:seq_jC2HinGU
#
# name: pSIBR-Cas9_Constitutive_sp4_acoC_HR
# id:seq_PjQcplir
#
# name: pSIBR-Cas9_int4_NT
# id:seq_cYL6PsVm
#
# name: pGNW2-PP_5322_14fRBS16_SePnuc*
# id:seq_CdNetGD6
#
# name: Copy of pSEVA621_Das1_PicPa_Dak_PicPa
# id:seq_vmIAerzK
#
# name: fbp knock out
# id:seq_JicNrySH
#
# name: p99 oYA015 and oYA016 check
# id:seq_pdQQQv9N
#
# name: Copy of P. putida KT2440
# id:seq_bi3yQnT5
#
# name: Copy of P. putida KT2440
# id:seq_NIlCrCI5
#
# name: pUC18-Y11520-GFP [2635-4416]
# id:seq_lv8s9Wdu
#
# name: pUC18-Y11520-GFP
# id:seq_YXENZyrd
#
# name: GFP_reverse
# id:seq_ZvH2zHvE
#
# name: GFP_forward
# id:seq_fihaXDE5
#
# name: Y11520_forward
# id:seq_LwE1nGo0
#
# name: Y11520_reverse
# id:seq_itf8aKAZ
#
# name: pUC18_reverse
# id:seq_GAB8FGFC
#
# name: pUC18_forward
# id:seq_jbnMZkv1
#
# name: GFP
# id:seq_4kkkwxK0
#
# name: pUC18
# id:seq_rnXgL58X
#
# name: Y11520
# id:seq_5mPI63MP
#
# name: Y11520
# id:seq_UTx7KngX
#
# name: p4S + Integrase + RBS C
# id:seq_cFDahxKM
#
# name: p4S + Integrase + RBS B
# id:seq_OxeTqLyT
#
# name: p4S + Integrase + RBS A
# id:seq_mbErhRtY
#
# name: Copy of pFLP2
# id:seq_qhPHdEkj
#
# name: p4S + RBS B eda + RBS 19 sacB
# id:seq_dDosLdod
#
# name: oEO_503
# id:seq_dpP98yr2
#
# name: oEO_504
# id:seq_V4PptFVz
#
# name: oEO_502
# id:seq_CiO5pX2w
#
# name: oEO_501
# id:seq_XyEwIBLp
#
# name: P. putida aspC region
# id:seq_P5qzFsF4
#
# name: P. putida aspC region after pYA003
# id:seq_wLwuXPv2
#
# name: pYA003 insert sequencing file
# id:seq_ZbJjKO8l
#
# name: pYA003 (pSNW2∙ΔaspC)
# id:seq_ljUaWkXq
#
# name: pYA003 insert
# id:seq_G4ztwJ0q
#
# name: P. putida aspC region after pYA003
# id:seq_H3DwoaGi
#
# name: P. putida aspC region
# id:seq_GC54zFTb
#
# name: oYA040 gacA SNP long forward
# id:seq_eWk4V9OK
#
# name: oYA039 gacA SNP medium forward
# id:seq_lvVKxTXe
#
# name: oYA038 gacA SNP short forward
# id:seq_JAhmV4GF
#
# name: uvrYe197K after p97
# id:seq_xy7I5BNA
#
# name: tpiA knock out with Str cassette
# id:seq_OQKxcfM7
#
# name: pckA genomic sequence after Emil's plasmid
# id:seq_oPFhqp3P
#
# name: pESC-TRP-Pop2/4-Gib
# id:seq_vtshUrSb
#
# name: pESC-URA-Pop1/3-Gib
# id:seq_c06xNiJn
#
# name: pGNW2-PP_5322_14cRBS19_SePnuc*
# id:seq_ZQH6BvG5
#
# name: pGNW2-PP_5322_14cRBS16_SePnuc*
# id:seq_L3aN8aaQ
#
# name: pGNW2-PP_5322_14fRBS20_SePnuc*
# id:seq_t71dLTNj
#
# name: pGNW2-PP_5322_14fRBS19_SePnuc*
# id:seq_mqzIiDPO
#
# name: oEO_487
# id:seq_j7lwxubP
#
# name: oEO_486
# id:seq_gzTyNENq
#
# name: oEO_485
# id:seq_egZbrofw
#
# name: oEO_484
# id:seq_Xz3Sysvk
#
# name: oEO_483
# id:seq_efJGZx83
#
# name: oEO_482
# id:seq_pA3jApnX
#
# name: pSIBR-Cas9_Int4_NT_EV REV
# id:seq_dBnGo3qT
#
# name: pSIBR-Cas9_Int4_NT_EV FWD
# id:seq_vvyt2Fug
#
# name: pSEVA231 REV
# id:seq_Y0tiRUTU
#
# name: pSEVA231 REV
# id:seq_wH6qzIQT
#
# name: pSEVA231 REV
# id:seq_aOru0yep
#
# name: pSEVA231 REV
# id:seq_9tYW6bcs
#
# name: pSEVA231 REV
# id:seq_1xB584Gi
#
# name: pSEVA231 FWD
# id:seq_x2LhHAJ6
#
# name: pSEVA231 FWD
# id:seq_p7uqYQDc
#
# name: pSEVA231 FWD
# id:seq_jLDBxH3P
#
# name: pSEVA231 FWD
# id:seq_faEhQMEx
#
# name: pSEVA231 FWD
# id:seq_as6cgaqP
#
# name: pSEVA231 FWD
# id:seq_5CEP8yXZ
#
# name: pSEVA64MBEC-sacB REV
# id:seq_rVIcWCkz
#
# name: pSEVA64MBEC-sacB REV
# id:seq_bVrBUqpS
#
# name: pSEVA64MBEC-sacB REV
# id:seq_b2Jv6fu7
#
# name: pSEVA64MBEC-sacB FWD
# id:seq_Y3g7HLz0
#
# name: pSEVA64MBEC-sacB FWD
# id:seq_ow4MCxL7
#
# name: pSEVA64MBEC-sacB FWD
# id:seq_Ikj1S2E7
#
# name: pSEVA64MBEC (SEVArised) REV
# id:seq_OaEurT3A
#
# name: pSEVA64MBEC (SEVArised) FWD
# id:seq_cJUGduEV
#
# name: oEO_419
# id:seq_GaITgA6p
#
# name: pSIBR-Cas9_int4_NT REV
# id:seq_ypWcBzFJ
#
# name: pSIBR-Cas9_int4_NT REV
# id:seq_TeuFPwEt
#
# name: pSIBR-Cas9_int4_NT REV
# id:seq_RwZvl9q7
#
# name: pSIBR-Cas9_int4_NT REV
# id:seq_LuGFKvhM
#
# name: pSIBR-Cas9_int4_NT FWD
# id:seq_aVZwPGxc
#
# name: pSIBR-Cas9_int4_NT FWD
# id:seq_9dtEJdKV
#
# name: pSEVA231 REV
# id:seq_vCGJM3JW
#
# name: pSEVA231 REV
# id:seq_hiKCVC3E
#
# name: pSEVA231 REV
# id:seq_gz8Qc2GY
#
# name: pSEVA231 REV
# id:seq_ghJjlwEN
#
# name: pSEVA231 FWD
# id:seq_XjdGagur
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Test Call
#       2 example_entities = benchling.dna_sequences.list()
# ----> 3 for page in example_entities:
#       4   for sequence in page:
#       5     print(f"name: {sequence.name}\nid:{sequence.id}\n")
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/pagination_helpers.py:203, in PageIterator.__next__(self)
#     197 def __next__(self) -> List[Model]:
#     198     if (
#     199         self._next_token is None
#     200         or len(self._next_token) > 0
#     201         or (self._first_page is not None and self._iterations_count == 1 and self._forced_iteration)
#     202     ):
# --> 203         return self._fetch_data()
#     204     raise StopIteration
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/pagination_helpers.py:146, in PageIterator._fetch_data(self)
#     144     return self._first_page if self._first_page else []
#     145 next_token = self._next_token if self._next_token else ""
# --> 146 response: Response[Model] = self._api_call(next_token)
#     147 result_body: Model = model_from_detailed(response)
#     148 self._approximate_length = self._length_extractor(response)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/services/v2/stable/dna_sequence_service.py:177, in DnaSequenceService.list.<locals>.api_call(next_token)
#     176 def api_call(next_token: NextToken) -> Response[DnaSequencesPaginatedList]:
# --> 177     return self._dna_sequences_page(
#     178         modified_at=modified_at,
#     179         name=name,
#     180         bases=bases,
#     181         folder_id=folder_id,
#     182         mentioned_in=mentioned_in,
#     183         project_id=project_id,
#     184         registry_id=registry_id,
#     185         schema_id=schema_id,
#     186         archive_reason=archive_reason,
#     187         mentions=mentions,
#     188         ids=ids,
#     189         entity_registry_ids_any_of=entity_registry_ids_any_of,
#     190         name_includes=name_includes,
#     191         names_any_of=names_any_of,
#     192         names_any_of_case_sensitive=names_any_of_case_sensitive,
#     193         creator_ids=creator_ids,
#     194         schema_fields=schema_fields,
#     195         sort=_translate_to_string_enum(ListDNASequencesSort, sort),
#     196         page_size=page_size,
#     197         next_token=next_token,
#     198         author_idsany_of=author_idsany_of,
#     199         returning=returning,
#     200     )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/retry_helpers.py:81, in retry_method.<locals>.func_with_retry_strategy_arg(self, retry_strategy, *args, **kwargs)
#      70 @backoff.on_exception(
#      71     backoff.expo,
#      72     BenchlingError,
#    (...)
#      77 )
#      78 def func_with_retries(*fargs, **fkwargs):
#      79     return f(*fargs, **fkwargs)
# ---> 81 return func_with_retries(self, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/retry_helpers.py:79, in retry_method.<locals>.func_with_retry_strategy_arg.<locals>.func_with_retries(*fargs, **fkwargs)
#      70 @backoff.on_exception(
#      71     backoff.expo,
#      72     BenchlingError,
#    (...)
#      77 )
#      78 def func_with_retries(*fargs, **fkwargs):
# ---> 79     return f(*fargs, **fkwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/decorators.py:19, in api_method.<locals>.wrapper(*args, **kwargs)
#      15 @wraps(f)
#      16 @retry_method
#      17 def wrapper(*args, **kwargs):
#      18     _log_function(f, args, kwargs)
# ---> 19     return f(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/services/v2/stable/dna_sequence_service.py:116, in DnaSequenceService._dna_sequences_page(self, modified_at, name, bases, folder_id, mentioned_in, project_id, registry_id, schema_id, archive_reason, mentions, sort, ids, entity_registry_ids_any_of, name_includes, names_any_of, names_any_of_case_sensitive, creator_ids, schema_fields, page_size, next_token, author_idsany_of, returning)
#      90 @api_method
#      91 def _dna_sequences_page(
#      92     self,
#    (...)
#     114     returning: Optional[Iterable[str]] = None,
#     115 ) -> Response[DnaSequencesPaginatedList]:
# --> 116     response = list_dna_sequences.sync_detailed(
#     117         client=self.client,
#     118         modified_at=none_as_unset(modified_at),
#     119         name=none_as_unset(name),
#     120         bases=none_as_unset(bases),
#     121         folder_id=none_as_unset(folder_id),
#     122         mentioned_in=none_as_unset(optional_array_query_param(mentioned_in)),
#     123         project_id=none_as_unset(project_id),
#     124         registry_id=none_as_unset(registry_id),
#     125         schema_id=none_as_unset(schema_id),
#     126         archive_reason=none_as_unset(archive_reason),
#     127         mentions=none_as_unset(optional_array_query_param(mentions)),
#     128         sort=none_as_unset(sort),
#     129         ids=none_as_unset(optional_array_query_param(ids)),
#     130         schema_fields=none_as_unset(schema_fields_query_param(schema_fields)),
#     131         entity_registry_idsany_of=none_as_unset(optional_array_query_param(entity_registry_ids_any_of)),
#     132         name_includes=none_as_unset(name_includes),
#     133         namesany_of=none_as_unset(optional_array_query_param(names_any_of)),
#     134         namesany_ofcase_sensitive=none_as_unset(optional_array_query_param(names_any_of_case_sensitive)),
#     135         creator_ids=none_as_unset(optional_array_query_param(creator_ids)),
#     136         page_size=none_as_unset(page_size),
#     137         next_token=none_as_unset(next_token),
#     138         author_idsany_of=none_as_unset(optional_array_query_param(author_idsany_of)),
#     139         returning=none_as_unset(optional_array_query_param(returning)),
#     140     )
#     141     raise_for_status(response)
#     142     return response
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_api_client/v2/stable/api/dna_sequences/list_dna_sequences.py:187, in sync_detailed(client, page_size, next_token, sort, modified_at, name, name_includes, bases, folder_id, mentioned_in, project_id, registry_id, schema_id, schema_fields, archive_reason, mentions, ids, entity_registry_idsany_of, namesany_of, namesany_ofcase_sensitive, creator_ids, author_idsany_of, returning)
#     135 def sync_detailed(
#     136     *,
#     137     client: Client,
#    (...)
#     159     returning: Union[Unset, str] = UNSET,
#     160 ) -> Response[Union[DnaSequencesPaginatedList, BadRequestError]]:
#     161     kwargs = _get_kwargs(
#     162         client=client,
#     163         page_size=page_size,
#    (...)
#     184         returning=returning,
#     185     )
# --> 187     response = client.httpx_client.get(
#     188         **kwargs,
#     189     )
#     191     return _build_response(response=response)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:1054, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1037 def get(
#    1038     self,
#    1039     url: URLTypes,
#    (...)
#    1047     extensions: RequestExtensions | None = None,
#    1048 ) -> Response:
#    1049     """
#    1050     Send a `GET` request.
#    1051
#    1052     **Parameters**: See `httpx.request`.
#    1053     """
# -> 1054     return self.request(
#    1055         "GET",
#    1056         url,
#    1057         params=params,
#    1058         headers=headers,
#    1059         cookies=cookies,
#    1060         auth=auth,
#    1061         follow_redirects=follow_redirects,
#    1062         timeout=timeout,
#    1063         extensions=extensions,
#    1064     )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_transports/default.py:232, in HTTPTransport.handle_request(self, request)
#     218 assert isinstance(request.stream, SyncByteStream)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_transports/default.py:86, in map_httpcore_exceptions()
#      83     raise
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out

# %%
## Retrieve mixtures
# Filter by project_id : DDB-HD (src_z7wWBBPd)
example_mixtures = benchling.mixtures.list(project_id="src_z7wWBBPd")

mixture_list = []

for page in example_mixtures:
    for mixture in page:
        # print(f"id: {mixture.name}")
        comments_field = mixture.fields.get('Comments').text_value
        # print(comments_field)
        
        # Check if ingredients list is not empty
        if not mixture.ingredients:
              # print(f" Ingredients: None")
        else:
            print(f" Ingredients: ")
            for ingredient in mixture.ingredients:
                  # amount = ingredient.amount
                  # name = ingredient.component_entity.name
                  # units = ingredient.units.value if ingredient.units else "N/A"
                  # benchling_id = ingredient.component_entity.id
                  # chebi_id = ingredient.component_entity.entity_registry_id
                  medium_dict = {
                    "medium_id": mixture.id,
                    "medium_name": mixture.name,
                    "medium_entitytyRegistryId": mixture.entity_registry_id,
                    "medium_comments": comments_field if comments_field is not None else "No Comments",
                    "ingredients": {
                      "chebi_id": ingredient.component_entity.entity_registry_id,
                      "benchling_id": ingredient.component_entity.id,
                      "name": ingredient.component_entity.name,
                      "amount": ingredient.amount,
                      "units": ingredient.units.value if ingredient.units else "N/A",   
                    }
                  }
                  # print(f"  - {medium_dict["ingredients"]['benchling_id']}-({medium_dict["ingredients"]['chebi_id']})-{medium_dict[mixture.id]['name']}: {medium_dict[mixture.id]['amount']} {medium_dict[mixture.id]['units']}")
                  
              
            mixture_list.append(medium_dict)

# %%
# Retrieve Experiment attributes: {custom entity: Experiment}
experiments = benchling.custom_entities.list(project_id="src_z7wWBBPd")

experiment_list = []


for page in experiments:
  for experiment in page:
    print(experiment)
    # experiment_name = experiment.fields.additional_properties.get("Experiment").display_value
    experiment_purpose = experiment.fields.get("Purpose")
    experiment_dict= {
      # "experiment_name": experiment_name,
      "experiment_name": experiment.name,
      "experiment_id": experiment.id,
      "experiment_entityRegistryId": experiment.entity_registry_id,
      "experiment_purpose": experiment_purpose

    }

    # print(f"name: {experiment.name}\nid:{experiment.id}\n")
    # print(f"purpose: {experiment_purpose}\n")
    experiment_list.append(experiment_dict)
# Out:
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_zM5PzQwx', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023853', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='795', is_multi=False, text_value='795', type=<FieldType.FLOAT: 'float'>, unit=None, value=795.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_YNDFXFQK', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023838', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='840', is_multi=False, text_value='840', type=<FieldType.FLOAT: 'float'>, unit=None, value=840.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_xxSI1aQm', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023846', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='894', is_multi=False, text_value='894', type=<FieldType.FLOAT: 'float'>, unit=None, value=894.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_Tq6PkOPZ', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023843', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='744', is_multi=False, text_value='744', type=<FieldType.FLOAT: 'float'>, unit=None, value=744.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_rqvcQIbv', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023845', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='846', is_multi=False, text_value='846', type=<FieldType.FLOAT: 'float'>, unit=None, value=846.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_RGeLOM0k', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023852', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='972', is_multi=False, text_value='972', type=<FieldType.FLOAT: 'float'>, unit=None, value=972.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_QS1mFfUU', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023847', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='696', is_multi=False, text_value='696', type=<FieldType.FLOAT: 'float'>, unit=None, value=696.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_oqX0u0X9', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023840', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='489', is_multi=False, text_value='489', type=<FieldType.FLOAT: 'float'>, unit=None, value=489.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_LxnlhtCW', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023857', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='909', is_multi=False, text_value='909', type=<FieldType.FLOAT: 'float'>, unit=None, value=909.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_KKYa9UrW', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023836', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='699', is_multi=False, text_value='699', type=<FieldType.FLOAT: 'float'>, unit=None, value=699.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', type= ...
# CustomEntity(aliases=[], api_url='https://biosustain.benchling.com/api/v2/custom-entities/bfi_J8MsVYpM', archive_record=None, authors=[UserSummary(handle='petjen', id='ent_GFJemYEF', name='Peter Ehlert Jensen', additional_properties={})], created_at=datetime.datetime(2023, 9, 20, 12, 20, 54, 658845, tzinfo=tzutc()), creator=CustomEntityCreator(additional_properties={'handle': 'petjen', 'id': 'ent_GFJemYEF', 'name': 'Peter Ehlert Jensen'}), custom_fields=CustomFields(additional_properties={}), entity_registry_id='SEQSUB3023856', fields=Fields(additional_properties={'Antibody (if ChIP-Seq)': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.TEXT: 'text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Average library size (in bp)': Field(display_value='', is_multi=False, text_value='', type=<FieldType.INTEGER: 'integer'>, unit=None, value=None, additional_properties={}), 'Biological replicate #': Field(display_value='1', is_multi=False, text_value='1', type=<FieldType.INTEGER: 'integer'>, unit=None, value=1, additional_properties={}), 'Buffer': Field(display_value='Nuclease-free water (RNA only)', is_multi=False, text_value='Nuclease-free water (RNA only)', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_5rGm1y5t', additional_properties={}), 'Cell Line': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Comments': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.LONG_TEXT: 'long_text'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Concentration (ng/ul)': Field(display_value='1023', is_multi=False, text_value='1023', type=<FieldType.FLOAT: 'float'>, unit=None, value=1023.0, additional_properties={}), 'Experiment': Field(display_value='DDB_PD_120_AMBR', is_multi=False, text_value='DDB_PD_120_AMBR', type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='bfi_vIiHYXHR', additional_properties={}), 'FW primer': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Individual sequencing samples': Field(display_value=None, is_multi=True, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=[], additional_properties={}), 'Link to library pool': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Colony': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Diluted Sample in Media': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Microbiome Sample': Field(display_value=None, is_multi=False, text_value=None, type=<FieldType.ENTITY_LINK: 'entity_link'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value=None, additional_properties={}), 'Nucleic acid type': Field(display_value='Total RNA', is_multi=False, text_value='Total RNA', type=<FieldType.DROPDOWN: 'dropdown'>, unit=<benchling_api_client.v2.types.Unset object at 0x121c81ed0>, value='sfso_Qfifnoxo', additional_properties={}), 'OD600': Field(display_value='', is_multi=False, text_value='', ty ...
# ...
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 7
#       2 experiments = benchling.custom_entities.list(project_id="src_z7wWBBPd")
#       4 experiment_list = []
# ----> 7 for page in experiments:
#       8   for experiment in page:
#       9     print(experiment)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/pagination_helpers.py:203, in PageIterator.__next__(self)
#     197 def __next__(self) -> List[Model]:
#     198     if (
#     199         self._next_token is None
#     200         or len(self._next_token) > 0
#     201         or (self._first_page is not None and self._iterations_count == 1 and self._forced_iteration)
#     202     ):
# --> 203         return self._fetch_data()
#     204     raise StopIteration
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/pagination_helpers.py:146, in PageIterator._fetch_data(self)
#     144     return self._first_page if self._first_page else []
#     145 next_token = self._next_token if self._next_token else ""
# --> 146 response: Response[Model] = self._api_call(next_token)
#     147 result_body: Model = model_from_detailed(response)
#     148 self._approximate_length = self._length_extractor(response)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/services/v2/stable/custom_entity_service.py:162, in CustomEntityService.list.<locals>.api_call(next_token)
#     161 def api_call(next_token: NextToken) -> Response[CustomEntitiesPaginatedList]:
# --> 162     return self._custom_entities_page(
#     163         schema_id=schema_id,
#     164         modified_at=modified_at,
#     165         name=name,
#     166         name_includes=name_includes,
#     167         folder_id=folder_id,
#     168         mentioned_in=mentioned_in,
#     169         project_id=project_id,
#     170         registry_id=registry_id,
#     171         archive_reason=archive_reason,
#     172         mentions=mentions,
#     173         ids=ids,
#     174         entity_registry_ids_any_of=entity_registry_ids_any_of,
#     175         names_any_of=names_any_of,
#     176         names_any_of_case_sensitive=names_any_of_case_sensitive,
#     177         creator_ids=creator_ids,
#     178         schema_fields=schema_fields,
#     179         sort=_translate_to_string_enum(ListCustomEntitiesSort, sort),
#     180         page_size=page_size,
#     181         next_token=next_token,
#     182         author_idsany_of=author_idsany_of,
#     183         returning=returning,
#     184     )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/retry_helpers.py:81, in retry_method.<locals>.func_with_retry_strategy_arg(self, retry_strategy, *args, **kwargs)
#      70 @backoff.on_exception(
#      71     backoff.expo,
#      72     BenchlingError,
#    (...)
#      77 )
#      78 def func_with_retries(*fargs, **fkwargs):
#      79     return f(*fargs, **fkwargs)
# ---> 81 return func_with_retries(self, *args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/retry_helpers.py:79, in retry_method.<locals>.func_with_retry_strategy_arg.<locals>.func_with_retries(*fargs, **fkwargs)
#      70 @backoff.on_exception(
#      71     backoff.expo,
#      72     BenchlingError,
#    (...)
#      77 )
#      78 def func_with_retries(*fargs, **fkwargs):
# ---> 79     return f(*fargs, **fkwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/helpers/decorators.py:19, in api_method.<locals>.wrapper(*args, **kwargs)
#      15 @wraps(f)
#      16 @retry_method
#      17 def wrapper(*args, **kwargs):
#      18     _log_function(f, args, kwargs)
# ---> 19     return f(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_sdk/services/v2/stable/custom_entity_service.py:100, in CustomEntityService._custom_entities_page(self, schema_id, modified_at, name, name_includes, folder_id, mentioned_in, project_id, registry_id, archive_reason, mentions, sort, ids, entity_registry_ids_any_of, names_any_of, names_any_of_case_sensitive, creator_ids, schema_fields, page_size, next_token, author_idsany_of, returning)
#      75 @api_method
#      76 def _custom_entities_page(
#      77     self,
#    (...)
#      98     returning: Optional[Iterable[str]] = None,
#      99 ) -> Response[CustomEntitiesPaginatedList]:
# --> 100     response = list_custom_entities.sync_detailed(
#     101         client=self.client,
#     102         schema_id=none_as_unset(schema_id),
#     103         modified_at=none_as_unset(modified_at),
#     104         name=none_as_unset(name),
#     105         name_includes=none_as_unset(name_includes),
#     106         folder_id=none_as_unset(folder_id),
#     107         mentioned_in=none_as_unset(optional_array_query_param(mentioned_in)),
#     108         project_id=none_as_unset(project_id),
#     109         registry_id=none_as_unset(registry_id),
#     110         archive_reason=none_as_unset(archive_reason),
#     111         mentions=none_as_unset(optional_array_query_param(mentions)),
#     112         sort=none_as_unset(sort),
#     113         ids=none_as_unset(optional_array_query_param(ids)),
#     114         entity_registry_idsany_of=none_as_unset(optional_array_query_param(entity_registry_ids_any_of)),
#     115         namesany_of=none_as_unset(optional_array_query_param(names_any_of)),
#     116         namesany_ofcase_sensitive=none_as_unset(optional_array_query_param(names_any_of_case_sensitive)),
#     117         creator_ids=none_as_unset(optional_array_query_param(creator_ids)),
#     118         schema_fields=none_as_unset(schema_fields_query_param(schema_fields)),
#     119         page_size=none_as_unset(page_size),
#     120         next_token=none_as_unset(next_token),
#     121         author_idsany_of=none_as_unset(optional_array_query_param(author_idsany_of)),
#     122         returning=none_as_unset(optional_array_query_param(returning)),
#     123     )
#     124     raise_for_status(response)
#     125     return response
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/benchling_api_client/v2/stable/api/custom_entities/list_custom_entities.py:182, in sync_detailed(client, next_token, page_size, sort, modified_at, name, returning, name_includes, folder_id, mentioned_in, project_id, registry_id, schema_id, schema_fields, archive_reason, mentions, ids, namesany_of, namesany_ofcase_sensitive, entity_registry_idsany_of, creator_ids, author_idsany_of)
#     132 def sync_detailed(
#     133     *,
#     134     client: Client,
#    (...)
#     155     author_idsany_of: Union[Unset, str] = UNSET,
#     156 ) -> Response[Union[CustomEntitiesPaginatedList, BadRequestError]]:
#     157     kwargs = _get_kwargs(
#     158         client=client,
#     159         next_token=next_token,
#    (...)
#     179         author_idsany_of=author_idsany_of,
#     180     )
# --> 182     response = client.httpx_client.get(
#     183         **kwargs,
#     184     )
#     186     return _build_response(response=response)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:1054, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1037 def get(
#    1038     self,
#    1039     url: URLTypes,
#    (...)
#    1047     extensions: RequestExtensions | None = None,
#    1048 ) -> Response:
#    1049     """
#    1050     Send a `GET` request.
#    1051
#    1052     **Parameters**: See `httpx.request`.
#    1053     """
# -> 1054     return self.request(
#    1055         "GET",
#    1056         url,
#    1057         params=params,
#    1058         headers=headers,
#    1059         cookies=cookies,
#    1060         auth=auth,
#    1061         follow_redirects=follow_redirects,
#    1062         timeout=timeout,
#    1063         extensions=extensions,
#    1064     )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/homebrew/anaconda3/envs/fermentdb_env/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# Write Medium Data to JSON file
output_path = "../output/medium_with_recipe_benchling_export.json"
os.makedirs(os.path.dirname(output_path), exist_ok = True)


with open(output_path, "w") as json_file:
    json.dump(mixture_list, json_file, indent=4)

print(f"Exported mixtures to {output_path}")
# Out:
# Exported mixtures to ../output/medium_with_recipe_benchling_export.json

# %%
# Write Experiment Data to JSON file
output_path = "../output/experiment_benchling_export.json"
os.makedirs(os.path.dirname(output_path), exist_ok = True)


with open(output_path, "w") as json_file:
    json.dump(experiment_list, json_file, indent=4)

print(f"Exported mixtures to {output_path}")

# %%
# # Write to CSV
# output_path = "../output/medium_with_recipe_benchling_export.csv"
# os.makedirs(os.path.dirname(output_path), exist_ok = True)

# with open(output_path, "w", newline="") as out:
#     fieldnames = ["chebi_id", "benchling_id", "name", "amount", "units"]
#     writer = csv.DictWriter(out, fieldnames=fieldnames)
#     writer.writeheader()
#     writer.writerows(mixture_list)

# print(f"Exported mixtures to {output_path}")
